# %%
import os
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))  # Add the project root to sys.path

from utils.helper_methods import visualize_cv_splits_only_one_fold
import pandas as pd

# Load the dataset
# Define the root directory
root_dir = r"C:\Users\johan\OneDrive - Aarhus universitet\9. Semester\Deep Learning\data_terumo"

# Load metadata for use in dataset creation
metadata_df = pd.read_csv(root_dir + "/metadata.csv")

# Call the function to visualize the splits
visualize_cv_splits_only_one_fold(metadata_df, n_splits=10)

# %%
import os
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))  # Add the project root to sys.path

from utils.helper_methods import visualize_cv_splits
import pandas as pd

# Define the root directory
root_dir = r"D:\OneDrive - Aarhus Universitet\9. Semester\Deep Learning\data_gentuity"

# Load metadata for use in dataset creation
metadata_df = pd.read_csv(root_dir + "/metadata.csv")

# Call the function to visualize the splits
visualize_cv_splits(metadata_df, n_splits=5)
