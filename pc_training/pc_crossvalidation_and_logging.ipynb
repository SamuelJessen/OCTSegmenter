# %%
import os
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))  # Add the project root to sys.path
import os
import json
import numpy as np
from pathlib import Path
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms
from utils.oct_dataset import OCTDataset
from utils.models import UnetNoPretraining, MedSAM, ResNetUNetWithAttention
from utils.lossfunctions import DiceLoss, DiceBCELoss
from utils.helper_methods import trial_dirname_creator

# %%
import numpy as np
import os
import tempfile
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from filelock import FileLock
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau
from typing import Dict
import ray
from ray import train, tune
from ray.train import Checkpoint
from ray.tune.schedulers import ASHAScheduler
from ray import tune, air
from ray.air import session
from ray.tune.search.optuna import OptunaSearch
from ray.train import RunConfig, CheckpointConfig
from tqdm import tqdm
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import neptune
import segmentation_models_pytorch as smp
from segment_anything import sam_model_registry
os.environ["TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S"] = "0"

def train_model(config):
    if torch.cuda.is_available():
        device = torch.device("cuda:0")
    else:
        device = torch.device("cpu")

    if config["model"] == "Unet":
        # Initialize model with the hyperparameters from the config
        net = smp.Unet(
            encoder_name="resnet34",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
            encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
            in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
            classes=1,                      # model output channels (number of classes in your dataset)
            activation="sigmoid",           # output activation (sigmoid for binary segmentation)
        )
        if config["freeze_encoder"]:
            for param in net.encoder.parameters():
                param.requires_grad = False

    elif config["model"] == "DeepLabV3+":
        net = smp.DeepLabV3Plus(
            encoder_name="resnet34",
            encoder_weights="imagenet",
            in_channels=3,
            classes=1,
            activation="sigmoid",
        )
        if config["freeze_encoder"]:
            for param in net.encoder.parameters():
                param.requires_grad = False 
    
    elif config["model"] == "MedSam":
        MedSAM_CKPT_PATH = r"D:\OneDrive - Aarhus Universitet\9. Semester\Deep Learning\medsam\medsam_vit_b.pth"
        sam_model = sam_model_registry['vit_b'](checkpoint=MedSAM_CKPT_PATH)
        net = MedSAM(
                image_encoder=sam_model.image_encoder,
                mask_decoder=sam_model.mask_decoder,
                prompt_encoder=sam_model.prompt_encoder,
            ).to(device)
        
        if config["freeze_encoder"]:
            # Freeze the image encoder
            for param in net.image_encoder.parameters():
                param.requires_grad = False

    elif config["model"] == "AttentionUnet":
        net = ResNetUNetWithAttention()

        if(config["freeze_encoder"]):
            net = ResNetUNetWithAttention(freeze_entire_backbone=True)


    net.to(device)

    # Select optimizer based on the configuration
    if config["optimizer"] == "AdamW":
        optimizer = optim.AdamW(net.parameters(), lr=config["lr"])
    elif config["optimizer"] == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)
    elif config["optimizer"] == "RMSprop":
        optimizer = optim.RMSprop(net.parameters(), lr=config["lr"])

    # Select loss function based on the configuration
    if config["loss_function"] == "DiceLoss":
        criterion = DiceLoss()
    elif config["loss_function"] == "DiceBCELoss":
        criterion = DiceBCELoss()
    elif config["loss_function"] == "BCELoss":
        criterion = nn.BCELoss()

    transform = transforms.Compose([
        transforms.Resize((1024, 1024), interpolation=Image.NEAREST),
        transforms.ToTensor(),
    ])

    # Load existing checkpoint through `get_checkpoint()` API.
    if train.get_checkpoint():
        loaded_checkpoint = train.get_checkpoint()
        with loaded_checkpoint.as_directory() as loaded_checkpoint_dir:
            model_state, optimizer_state = torch.load(
                os.path.join(loaded_checkpoint_dir, "checkpoint.pt")
            )
            net.load_state_dict(model_state)
            optimizer.load_state_dict(optimizer_state)

    root_dir = config["root_dir"]
    folds= config["folds"]
    
    with open(os.path.join(root_dir, "metadata.csv"), "r") as f:
        metadata_df = pd.read_csv(f)
        skf = StratifiedKFold(n_splits=folds)
        splits = list(skf.split(metadata_df, metadata_df["unique_id"]))

    train_and_validate_cv(root_dir, config, splits, folds, transform, optimizer, criterion, net, device)


def train_and_validate_cv(root_dir, config, splits, folds, transform, optimizer, criterion, net, device, medsam=False):
    for fold in range(folds):
        # Train and validate the model
        print(f"Training on fold {fold+1} out of {folds}")
        
        # Initialize Neptune run
        run = neptune.init_run(
            project="OCTAA/OCTSegmenter",
            api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2MGU2NGNjMi0yNWE0LTRjNzgtOGNlNS1hZDdkMjJhYzYxMWUifQ==",
            name="training_and_validation",
            tags="terumo",
        )  # your credentials

        run["sys/group_tags"].add([
            str(config["model"]),
            str(config["freeze_encoder"]),
            str(config["loss_function"]), 
            str(config["optimizer"]), 
            f"Fold: {str(fold)}"
        ])  # Group tags

        # Log configuration parameters
        run["parameters"] = config

        train_indices, val_indices = splits[fold]

        train_dataset = OCTDataset(root_dir, indices=train_indices, transform=transform)
        val_dataset = OCTDataset(root_dir, indices=val_indices, transform=transform)

        trainloader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
        valloader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

        best_val_loss = float("inf")
        epochs = config["epochs"]
        no_improvement_epochs = 0
        patience = config["patience"]
        scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=10)
        
        for epoch in range(epochs):
            net.train()
            running_loss = 0.0
            epoch_steps= 0

            for i, data in enumerate(trainloader):
                if config["model"] == "MedSam":
                    images, masks, _, _ = data
                    images, masks = images.to(device), masks.to(device)

                     # Get image dimensions
                    batch_size, _, height, width = images.size()

                    # Create bounding boxes that cover the whole image
                    bboxes = torch.tensor([[0, 0, width, height]] * batch_size, dtype=torch.float32).unsqueeze(1).to(device)

                    optimizer.zero_grad()
                    outputs = net(images, bboxes)
                    loss = criterion(outputs, masks)
                    loss.backward()
                    optimizer.step()

                else:
                    images, masks, _, _ = data
                    images, masks = images.to(device), masks.to(device)

                    optimizer.zero_grad()
                    outputs = net(images)
                    loss = criterion(outputs, masks)
                    loss.backward()
                    optimizer.step()

                running_loss += loss.item() * images.size(0)

                epoch_steps += 1
                if i % 10 == 9:  # print every 10 mini-batches
                    print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                    loss.item()))


            # Calculate training loss and accuracy for the epoch
            train_loss = running_loss / len(trainloader.dataset)
            run["train_loss"].append(train_loss)  # Log training loss to neptune
            print(f"Epoch [{epoch+1}/{epochs}], Training Loss: {train_loss:.4f}")

            # Validation phase
            net.eval()
            val_loss = 0.0
            dice_loss = 0.0

            with torch.no_grad():  # No need to calculate gradients during validation
                for data in valloader:
                    if config["model"] == "MedSam":
                        images, masks, _, _ = data
                        images, masks = images.to(device), masks.to(device)

                        # Get image dimensions
                        batch_size, _, height, width = images.size()

                        # Create bounding boxes that cover the whole image
                        bboxes = torch.tensor([[0, 0, width, height]] * batch_size, dtype=torch.float32).unsqueeze(1).to(device)

                        outputs = net(images, bboxes)
                        loss = criterion(outputs, masks)
                        val_loss += loss.item() * images.size(0)

                    else:
                        images, masks, _, _ = data
                        images, masks = images.to(device), masks.to(device)

                        outputs = net(images)
                        loss = criterion(outputs, masks)
                        val_loss += loss.item() * images.size(0)

                    # Calculate Dice loss
                    dice = DiceLoss()
                    loss = dice(outputs, masks)
                    dice_loss += loss.item() * images.size(0)
            
            # Calculate validation loss and accuracy
            val_loss = val_loss / len(valloader.dataset)
            avg_dice_loss = dice_loss / len(valloader.dataset)
            scheduler.step(val_loss) # Adjust learning rate based on validation loss
            run["val_loss"].append(val_loss)  # Log validation loss
            run["dice_loss"].append(avg_dice_loss)  # Log Dice loss
            print(f"Epoch [{epoch+1}/{epochs}], Validation Loss: {val_loss:.4f}")

            with tempfile.TemporaryDirectory() as temp_checkpoint_dir:
                path = os.path.join(temp_checkpoint_dir, "checkpoint.pt")
                torch.save(
                    (net.state_dict(), optimizer.state_dict()), path
                )
                checkpoint = Checkpoint.from_directory(temp_checkpoint_dir)
                train.report(
                    {"loss": val_loss, "accuracy": 1 - avg_dice_loss, "dice_loss": avg_dice_loss, "fold": fold},
                    checkpoint=checkpoint,
                )

            # Check if validation loss improves
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                no_improvement_epochs = 0
                print(f"Validation loss improved to {val_loss:.4f}. Saving checkpoint.")
                
            else:
                no_improvement_epochs += 1
                print(f"Validation loss did not improve. Best so far: {best_val_loss:.4f}")
            
            if no_improvement_epochs >= patience:
                print(f"Stopping early. No improvement in {patience} epochs.")
                run["early_stopping"] = True
                break

        run.stop()
        print("Finished Training")

    
def test_best_model(best_result):
    
    # Initialize Neptune run
    run = neptune.init_run(
        project="OCTAA/OCTSegmenter",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2MGU2NGNjMi0yNWE0LTRjNzgtOGNlNS1hZDdkMjJhYzYxMWUifQ==",
        name="best_model_test",
        tags="gentuity"  
    )  # your credentials

    # Log configuration parameters
    run["parameters"] = best_result.config

    if torch.cuda.is_available():
        device = torch.device("cuda:0")
    else:
        device = torch.device("cpu")
    best_trained_model = UnetNoPretraining().to(device)

    checkpoint_path = os.path.join(best_result.checkpoint.to_directory(), "checkpoint.pt")

    model_state, optimizer_state = torch.load(checkpoint_path, weights_only=True)
    best_trained_model.load_state_dict(model_state)

    transform = transforms.Compose([
        transforms.Resize((1024, 1024), interpolation=Image.NEAREST),
        transforms.ToTensor(),
    ])

    root_dir = r"D:\OneDrive - Aarhus Universitet\9. Semester\Deep Learning\data_gentuity"

    test_dataset = OCTDataset(root_dir, transform=transform, train=False, is_gentuity=True)
    testloader = DataLoader(test_dataset, batch_size=best_result.config["batch_size"], shuffle=False)

    criterion = DiceLoss()

    total_loss = 0.0
    with torch.no_grad():  # Disable gradient calculation
        for data in testloader:
            if best_result.config["model"] == "MedSam":
                images, masks, _, _ = data
                images, masks = images.to(device), masks.to(device)

                # Get image dimensions
                batch_size, _, height, width = images.size()

                # Create bounding boxes that cover the whole image
                bboxes = torch.tensor([[0, 0, width, height]] * batch_size, dtype=torch.float32).unsqueeze(1).to(device)

                outputs = best_trained_model(images, bboxes)
                predicted = (outputs > 0.5).float()
                loss = criterion(predicted, masks)
                total_loss += loss.item() * images.size(0)

            else:
                images, masks, _, _ = data
                images, masks = images.to(device), masks.to(device)

                outputs = best_trained_model(images)
                predicted = (outputs > 0.5).float()
                loss = criterion(predicted, masks)
                total_loss += loss.item() * images.size(0)

    # Calculate average loss and accuracy
    total_loss /= len(testloader.dataset)
    accuracy = 1 - loss

    run["test_loss"] = total_loss
    run.stop()
    print(f"Test Loss: {total_loss:.4f}, Test Accuracy: {accuracy:.4f}")

# %%
def main(num_samples, gpus_per_trial, epochs, smoke_test, folds):
    if smoke_test:
        root_dir = r"D:\OneDrive - Aarhus Universitet\9. Semester\Deep Learning\data_terumo_smoke_test"

    else:
        print("Using full dataset")
    
    config = {
        "root_dir": root_dir,
        "lr": tune.loguniform(1e-6, 1e-2),
        "epochs": epochs,
        "smoke_test": smoke_test,
        "batch_size": tune.choice([4]),
        "optimizer": tune.grid_search(["AdamW", "SGD", "RMSprop"]),
        "folds": folds,
        "patience": 20,
        "loss_function": tune.grid_search(["DiceLoss", "BCELoss", "DiceBCELoss"]),
        "model": tune.grid_search(["AttentionUnet", "Unet", "DeepLabV3+", "MedSam"]),
        "freeze_encoder": tune.grid_search([True, False]),
    }

    # ASHA SCHEDULER, BUT WILL NOT BE USED
    # scheduler = ASHAScheduler(
    #     max_t=5,
    #     grace_period=5,
    #     reduction_factor=2
    # )

    # Define your checkpoint configuration
    checkpoint_config = CheckpointConfig(
        num_to_keep=1,  # Only keep the best checkpoint
        checkpoint_score_attribute="loss",  # The metric used to determine the best checkpoint
        checkpoint_score_order="min",  # Keep the checkpoint with the lowest loss
    )

    # Define the run config with the checkpoint config
    run_config = RunConfig(checkpoint_config=checkpoint_config)

    tuner = tune.Tuner(
        tune.with_resources(
            tune.with_parameters(train_model),
            resources={"cpu": 2, "gpu": gpus_per_trial}
        ),
        tune_config=tune.TuneConfig(
            metric="dice_loss",
            mode="min",
            num_samples=num_samples,
            trial_dirname_creator=trial_dirname_creator,
        ),
        param_space=config,
        run_config=run_config,
    )
    results = tuner.fit()
    
    best_result = results.get_best_result("dice_loss", "min")

    print("Best trial config: {}".format(best_result.config))
    print("Best trial final validation loss: {}".format(
        best_result.metrics["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_result.metrics["accuracy"]))

    test_best_model(best_result)

main(num_samples=2, gpus_per_trial=1, epochs=2, smoke_test=True, folds=5)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-11-28 22:50:21</td></tr>
# <tr><td>Running for: </td><td>00:00:32.11        </td></tr>
# <tr><td>Memory:      </td><td>10.4/15.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/8 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                                                                         </th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_cv_b0d04_00000</td><td style="text-align: right;">           1</td><td>C:/Users/johan/AppData/Local/Temp/ray/session_2024-11-28_22-49-39_609521_2844/artifacts/2024-11-28_22-49-49/train_model_cv_2024-11-28_22-49-38/driver_artifacts/trial_b0d04_00000_lr=6.9e-06_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th>freeze_encoder  </th><th>loss_function  </th><th style="text-align: right;">         lr</th><th>model        </th><th>optimizer  </th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_cv_b0d04_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceLoss       </td><td style="text-align: right;">5.7109e-06 </td><td>AttentionUnet</td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>BCELoss        </td><td style="text-align: right;">0.000110082</td><td>AttentionUnet</td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>BCELoss        </td><td style="text-align: right;">0.000315215</td><td>AttentionUnet</td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceBCELoss    </td><td style="text-align: right;">0.000550301</td><td>AttentionUnet</td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceBCELoss    </td><td style="text-align: right;">9.06622e-06</td><td>AttentionUnet</td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceLoss       </td><td style="text-align: right;">1.01953e-05</td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceLoss       </td><td style="text-align: right;">0.00252428 </td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>BCELoss        </td><td style="text-align: right;">0.00830767 </td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>BCELoss        </td><td style="text-align: right;">0.00192881 </td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00010</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceBCELoss    </td><td style="text-align: right;">1.31017e-05</td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00011</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceBCELoss    </td><td style="text-align: right;">0.00497087 </td><td>Unet         </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00012</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceLoss       </td><td style="text-align: right;">4.76101e-05</td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00013</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceLoss       </td><td style="text-align: right;">2.28495e-06</td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00014</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>BCELoss        </td><td style="text-align: right;">0.00145873 </td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00015</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>BCELoss        </td><td style="text-align: right;">0.00149364 </td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00016</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceBCELoss    </td><td style="text-align: right;">0.00922086 </td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00017</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceBCELoss    </td><td style="text-align: right;">5.98311e-05</td><td>DeepLabV3+   </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00018</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>DiceLoss       </td><td style="text-align: right;">7.50218e-06</td><td>MedSam       </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00019</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>DiceLoss       </td><td style="text-align: right;">5.38289e-05</td><td>MedSam       </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00020</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>True            </td><td>BCELoss        </td><td style="text-align: right;">2.91079e-05</td><td>MedSam       </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_00021</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td>False           </td><td>BCELoss        </td><td style="text-align: right;">0.000702273</td><td>MedSam       </td><td>AdamW      </td></tr>
# <tr><td>train_model_cv_b0d04_0
# (train_model_cv pid=13784) Training on fold 1 out of 5
# (train_model_cv pid=13784) [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/OCTAA/OCTSegmenter/e/OCT-192
# 2024-11-28 22:50:17,360	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_cv_b0d04_00000
# Traceback (most recent call last):
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\_private\worker.py", line 2656, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13784, ip=127.0.0.1, actor_id=ca3ff241d87567f58f287f7601000000, repr=train_model_cv)
#   File "python\ray\_raylet.pyx", line 1901, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1842, in ray._raylet.execute_task.function_executor
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 248, in _trainable_func
#     output = fn()
#              ^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\tune\trainable\util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\johan\AppData\Local\Temp\ipykernel_2844\4267149241.py", line 123, in train_model_cv
#   File "C:\Users\johan\AppData\Local\Temp\ipykernel_2844\4267149241.py", line 191, in train_and_validate
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\OCTSegmenter\utils\models.py", line 106, in forward
#     d0 = self.final_decoder(d0)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\container.py", line 219, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\conv.py", line 458, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\torch\nn\modules\conv.py", line 454, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cuDNN error: CUDNN_STATUS_BAD_PARAM_STREAM_MISMATCH
# 2024-11-28 22:50:21,379	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-11-28 22:50:21,483	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38' in 0.0920s.
# 2024-11-28 22:50:31,854	ERROR tune.py:1037 -- Trials did not complete: [train_model_cv_b0d04_00000]
# 2024-11-28 22:50:31,855	INFO tune.py:1041 -- Total run time: 42.61 seconds (32.01 seconds for the tuning loop).
# 2024-11-28 22:50:31,856	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38", trainable=...)
# 2024-11-28 22:50:31,939	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 143 trial(s):
# - train_model_cv_b0d04_00001: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00001: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00001_lr=5.7e-06_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00002: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00002: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00002_lr=1.1e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00003: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00003: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00003_lr=3.2e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00004: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00004: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00004_lr=5.5e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00005: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00005: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00005_lr=9.1e-06_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00006: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00006: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00006_lr=1.0e-05_opt=AdamW_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00007: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00007: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00007_lr=2.5e-03_opt=AdamW_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00008: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00008: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00008_lr=8.3e-03_opt=AdamW_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00009: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00009: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00009_lr=1.9e-03_opt=AdamW_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00010: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00010: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00010_lr=1.3e-05_opt=AdamW_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00011: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00011: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00011_lr=5.0e-03_opt=AdamW_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00012: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00012: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00012_lr=4.8e-05_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00013: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00013: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00013_lr=2.3e-06_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00014: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00014: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00014_lr=1.5e-03_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00015: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00015: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00015_lr=1.5e-03_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00016: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00016: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00016_lr=9.2e-03_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00017: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00017: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00017_lr=6.0e-05_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00018: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00018: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00018_lr=7.5e-06_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00019: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00019: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00019_lr=5.4e-05_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00020: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00020: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00020_lr=2.9e-05_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00021: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00021: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00021_lr=7.0e-04_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00022: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00022: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00022_lr=4.5e-04_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00023: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00023: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00023_lr=5.1e-04_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00024: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00024: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00024_lr=3.4e-04_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00025: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00025: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00025_lr=1.1e-03_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00026: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00026: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00026_lr=1.9e-05_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00027: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00027: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00027_lr=6.6e-05_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00028: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00028: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00028_lr=1.1e-03_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00029: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00029: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00029_lr=4.1e-03_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00030: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00030: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00030_lr=5.4e-05_opt=SGD_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00031: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00031: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00031_lr=7.4e-04_opt=SGD_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00032: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00032: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00032_lr=6.6e-05_opt=SGD_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00033: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00033: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00033_lr=3.2e-04_opt=SGD_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00034: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00034: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00034_lr=4.3e-05_opt=SGD_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00035: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00035: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00035_lr=9.7e-03_opt=SGD_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00036: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00036: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00036_lr=1.8e-06_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00037: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00037: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00037_lr=7.4e-05_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00038: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00038: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00038_lr=1.1e-06_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00039: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00039: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00039_lr=1.2e-03_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00040: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00040: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00040_lr=1.6e-04_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00041: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00041: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00041_lr=5.3e-05_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00042: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00042: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00042_lr=1.9e-03_opt=SGD_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00043: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00043: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00043_lr=5.8e-05_opt=SGD_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00044: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00044: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00044_lr=7.6e-03_opt=SGD_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00045: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00045: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00045_lr=2.0e-04_opt=SGD_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00046: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00046: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00046_lr=1.6e-04_opt=SGD_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00047: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00047: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00047_lr=1.2e-03_opt=SGD_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00048: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00048: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00048_lr=3.4e-05_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00049: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00049: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00049_lr=6.5e-03_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00050: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00050: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00050_lr=6.5e-04_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00051: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00051: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00051_lr=7.1e-03_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00052: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00052: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00052_lr=1.7e-04_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00053: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00053: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00053_lr=3.5e-06_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00054: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00054: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00054_lr=5.4e-03_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00055: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00055: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00055_lr=1.8e-03_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00056: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00056: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00056_lr=4.0e-04_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00057: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00057: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00057_lr=1.4e-03_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00058: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00058: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00058_lr=1.5e-03_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00059: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00059: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00059_lr=1.1e-03_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00060: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00060: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00060_lr=8.3e-06_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00061: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00061: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00061_lr=3.4e-03_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00062: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00062: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00062_lr=6.2e-05_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00063: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00063: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00063_lr=6.3e-05_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00064: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00064: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00064_lr=1.6e-06_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00065: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00065: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00065_lr=3.0e-06_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00066: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00066: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00066_lr=3.0e-04_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00067: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00067: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00067_lr=7.3e-03_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00068: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00068: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00068_lr=2.7e-06_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00069: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00069: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00069_lr=3.0e-05_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00070: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00070: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00070_lr=3.0e-04_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00071: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00071: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00071_lr=4.9e-03_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00072: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00072: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00072_lr=2.9e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00073: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00073: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00073_lr=9.1e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00074: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00074: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00074_lr=4.6e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00075: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00075: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00075_lr=3.8e-06_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00076: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00076: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00076_lr=1.6e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00077: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00077: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00077_lr=2.2e-04_opt=AdamW_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00078: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00078: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00078_lr=9.2e-06_opt=AdamW_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00079: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00079: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00079_lr=1.1e-03_opt=AdamW_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00080: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00080: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00080_lr=1.8e-03_opt=AdamW_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00081: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00081: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00081_lr=1.2e-05_opt=AdamW_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00082: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00082: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00082_lr=4.3e-05_opt=AdamW_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00083: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00083: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00083_lr=4.7e-03_opt=AdamW_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00084: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00084: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00084_lr=1.3e-03_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00085: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00085: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00085_lr=4.9e-06_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00086: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00086: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00086_lr=2.0e-06_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00087: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00087: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00087_lr=4.5e-05_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00088: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00088: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00088_lr=4.9e-06_opt=AdamW_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00089: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00089: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00089_lr=7.5e-05_opt=AdamW_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00090: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00090: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00090_lr=5.2e-04_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00091: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00091: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00091_lr=4.2e-05_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00092: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00092: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00092_lr=1.6e-03_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00093: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00093: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00093_lr=4.6e-06_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00094: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00094: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00094_lr=4.2e-06_opt=AdamW_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00095: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00095: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00095_lr=2.9e-04_opt=AdamW_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00096: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00096: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00096_lr=1.2e-06_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00097: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00097: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00097_lr=1.4e-03_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00098: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00098: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00098_lr=5.8e-05_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00099: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00099: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00099_lr=1.1e-04_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00100: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00100: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00100_lr=2.3e-05_opt=SGD_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00101: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00101: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00101_lr=1.0e-06_opt=SGD_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00102: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00102: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00102_lr=1.8e-03_opt=SGD_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00103: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00103: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00103_lr=1.4e-06_opt=SGD_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00104: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00104: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00104_lr=2.9e-04_opt=SGD_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00105: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00105: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00105_lr=1.7e-03_opt=SGD_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00106: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00106: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00106_lr=1.1e-03_opt=SGD_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00107: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00107: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00107_lr=2.3e-05_opt=SGD_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00108: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00108: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00108_lr=4.6e-03_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00109: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00109: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00109_lr=2.5e-03_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00110: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00110: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00110_lr=7.4e-06_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00111: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00111: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00111_lr=4.8e-06_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00112: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00112: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00112_lr=7.3e-04_opt=SGD_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00113: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00113: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00113_lr=1.2e-06_opt=SGD_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00114: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00114: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00114_lr=1.0e-03_opt=SGD_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00115: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00115: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00115_lr=2.1e-04_opt=SGD_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00116: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00116: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00116_lr=3.3e-04_opt=SGD_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00117: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00117: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00117_lr=4.5e-06_opt=SGD_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00118: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00118: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00118_lr=4.4e-04_opt=SGD_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00119: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00119: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00119_lr=1.8e-03_opt=SGD_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00120: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00120: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00120_lr=7.0e-06_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00121: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00121: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00121_lr=6.3e-04_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00122: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00122: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00122_lr=5.5e-06_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00123: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00123: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00123_lr=2.6e-05_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00124: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00124: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00124_lr=6.6e-04_opt=RMSprop_bs=4_model=AttentionUnet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00125: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00125: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00125_lr=5.0e-06_opt=RMSprop_bs=4_model=AttentionUnet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00126: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00126: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00126_lr=1.1e-06_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00127: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00127: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00127_lr=2.3e-05_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00128: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00128: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00128_lr=3.1e-06_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00129: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00129: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00129_lr=1.0e-06_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00130: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00130: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00130_lr=1.6e-04_opt=RMSprop_bs=4_model=Unet_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00131: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00131: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00131_lr=5.9e-03_opt=RMSprop_bs=4_model=Unet_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00132: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00132: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00132_lr=1.6e-05_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00133: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00133: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00133_lr=1.0e-04_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00134: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00134: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00134_lr=1.5e-03_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00135: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00135: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00135_lr=1.1e-04_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00136: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00136: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00136_lr=3.0e-03_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00137: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00137: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00137_lr=1.1e-05_opt=RMSprop_bs=4_model=DeepLabV3+_freeze=False_loss=DiceBCELoss')
# - train_model_cv_b0d04_00138: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00138: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00138_lr=5.6e-03_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=DiceLoss')
# - train_model_cv_b0d04_00139: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00139: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00139_lr=1.3e-04_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=DiceLoss')
# - train_model_cv_b0d04_00140: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00140: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00140_lr=3.9e-05_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=BCELoss')
# - train_model_cv_b0d04_00141: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00141: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00141_lr=3.0e-05_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=BCELoss')
# - train_model_cv_b0d04_00142: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00142: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00142_lr=2.5e-03_opt=RMSprop_bs=4_model=MedSam_freeze=True_loss=DiceBCELoss')
# - train_model_cv_b0d04_00143: FileNotFoundError('Could not fetch metrics for train_model_cv_b0d04_00143: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-28_22-49-38/trial_b0d04_00143_lr=1.2e-05_opt=RMSprop_bs=4_model=MedSam_freeze=False_loss=DiceBCELoss')
# 2024-11-28 22:50:32,215	WARNING experiment_analysis.py:558 -- Could not find best trial. Did you pass the correct `metric` parameter?

# %%
import os
from ray import tune
from ray.train import Result

storage_path = r"C:\Users\johan\ray_results"
exp_name = "train_model_cv_2024-11-26_18-30-35"
experiment_path = os.path.join(storage_path, exp_name)
print(f"Loading results from {experiment_path}...")

restored_tuner = tune.Tuner.restore(experiment_path, trainable=train_model_cv)
result_grid = restored_tuner.get_results()

# Check if there have been errors
if result_grid.errors:
    print("One of the trials failed!")
else:
    print("No errors!")
    
# Get the result with the maximum test set `mean_accuracy`
best_result: Result = result_grid.get_best_result()

# Load the best checkpoint if it exists
if best_result.checkpoint:
    checkpoint_path = os.path.join(best_result.checkpoint.to_directory(), "checkpoint.pt")
else:
    raise ValueError("No checkpoint found for the best result.")
# Out:
# Loading results from C:\Users\johan\ray_results\train_model_cv_2024-11-26_18-30-35...
# One of the trials failed!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 24
#      22 # Load the best checkpoint if it exists
#      23 if best_result.checkpoint:
# ---> 24     checkpoint_path = os.path.join(best_result.checkpoint.to_directory(), "checkpoint.pt")
#      25 else:
#      26     raise ValueError("No checkpoint found for the best result.")
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\train\_checkpoint.py:216, in Checkpoint.to_directory(self, path)
#     212 try:
#     213     # Timeout 0 means there will be only one attempt to acquire
#     214     # the file lock. If it cannot be acquired, throw a TimeoutError
#     215     with TempFileLock(local_path, timeout=0):
# --> 216         _download_from_fs_path(
#     217             fs=self.filesystem, fs_path=self.path, local_path=local_path
#     218         )
#     219 except TimeoutError:
#     220     # if the directory is already locked, then wait but do not do anything.
#     221     with TempFileLock(local_path, timeout=-1):
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\train\_internal\storage.py:184, in _download_from_fs_path(fs, fs_path, local_path, filelock)
#     182 if not exists_before:
#     183     shutil.rmtree(local_path, ignore_errors=True)
# --> 184 raise e
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\train\_internal\storage.py:177, in _download_from_fs_path(fs, fs_path, local_path, filelock)
#     175 if filelock:
#     176     with TempFileLock(f"{os.path.normpath(local_path)}.lock"):
# --> 177         _pyarrow_fs_copy_files(fs_path, local_path, source_filesystem=fs)
#     178 else:
#     179     _pyarrow_fs_copy_files(fs_path, local_path, source_filesystem=fs)
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\ray\train\_internal\storage.py:110, in _pyarrow_fs_copy_files(source, destination, source_filesystem, destination_filesystem, **kwargs)
#     107 # Use a large chunk size to speed up large checkpoint transfers.
#     108 kwargs.setdefault("chunk_size", 64 * 1024 * 1024)
# --> 110 return pyarrow.fs.copy_files(
#     111     source,
#     112     destination,
#     113     source_filesystem=source_filesystem,
#     114     destination_filesystem=destination_filesystem,
#     115     **kwargs,
#     116 )
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\pyarrow\fs.py:259, in copy_files(source, destination, source_filesystem, destination_filesystem, chunk_size, use_threads)
#     257 if file_info.type == FileType.Directory:
#     258     source_sel = FileSelector(source_path, recursive=True)
# --> 259     _copy_files_selector(source_fs, source_sel,
#     260                          destination_fs, destination_path,
#     261                          chunk_size, use_threads)
#     262 else:
#     263     _copy_files(source_fs, source_path,
#     264                 destination_fs, destination_path,
#     265                 chunk_size, use_threads)
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\pyarrow\_fs.pyx:1630, in pyarrow._fs._copy_files_selector()
#
# File c:\Users\johan\anaconda3\envs\dl\Lib\site-packages\pyarrow\error.pxi:91, in pyarrow.lib.check_status()
#
# OSError: [WinError 112] Failed copying 'C:/Users/johan/ray_results/train_model_cv_2024-11-26_18-30-35/trial_2b60a_00035_lr=1.0e-04_opt=RMSprop_bs=4/checkpoint_000004/checkpoint.pt' to 'C:/Users/johan/AppData/Local/Temp/checkpoint_tmp_eb1ac5460b9145e2847271a019179487/checkpoint.pt'. Detail: [Windows error 112] Der er ikke tilstrækkelig plads på disken.

# %%
import os
from ray import tune
from ray.train import Result

storage_path = r"C:\Users\johan\ray_results"
exp_name = "train_model_cv_2024-11-26_16-31-22"
experiment_path = os.path.join(storage_path, exp_name)
print(f"Loading results from {experiment_path}...")

restored_tuner = tune.Tuner.restore(experiment_path, trainable=train_model_cv)
result_grid = restored_tuner.get_results()

# Check if there have been errors
if result_grid.errors:
    print("One of the trials failed!")
else:
    print("No errors!")

num_results = len(result_grid)
print("Number of results:", num_results)

# Iterate over results
for i, result in enumerate(result_grid):
    if result.error:
        print(f"Trial #{i} had an error:", result.error)
        continue

    print(f"Trial #{i} finished successfully with a loss of: {result.metrics['loss']}")

results_df = result_grid.get_dataframe()
results_df[["training_iteration", "loss"]]

print("Shortest training time:", results_df["time_total_s"].min())
print("Longest training time:", results_df["time_total_s"].max())

ax = None
for result in result_grid:
    label = f"lr={result.config['lr']:.4f}, batch_size={result.config['batch_size']}, optimizer={result.config['optimizer']}, fold={result.config['fold']}"
    if ax is None:
        ax = result.metrics_dataframe.plot("training_iteration", "loss", label=label)
    else:
        result.metrics_dataframe.plot("training_iteration", "loss", ax=ax, label=label)
ax.set_title("Loss vs. Training Iteration for All Trials")
ax.set_ylabel("Loss")

# Get the result with the maximum test set `mean_accuracy`
best_result: Result = result_grid.get_best_result()

print("Best trial config: {}".format(best_result.config))

# Get the best trial's final loss and accuracy
best_loss = best_result.metrics["loss"]
print("Best trial final test set loss: {}".format(best_loss))
best_accuracy = best_result.metrics["accuracy"]
print("Best trial final test set accuracy: {}".format(best_accuracy))

# Load the best model
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")

best_trained_model = UnetNoPretraining().to(device)

# Load the best checkpoint
checkpoint_path = os.path.join(best_result.checkpoint.to_directory(), "checkpoint.pt")

model_state, optimizer_state = torch.load(checkpoint_path, weights_only=True)
best_trained_model.load_state_dict(model_state)

# Set the model to evaluation mode
best_trained_model.eval()

# Load a sample image from the test dataset
root_dir = r"D:\OneDrive - Aarhus Universitet\9. Semester\Deep Learning\data_gentuity"
transform = transforms.Compose([
    transforms.Resize((256, 256), interpolation=Image.NEAREST),
    transforms.ToTensor(),
])
test_dataset = OCTDataset(root_dir, transform=transform, train=False, is_gentuity=True)
random_indices = np.random.choice(len(test_dataset), 1, replace=False)
sample_image, sample_mask, _, _ = test_dataset[random_indices[0]]  # Change the index to load a different sample

# Move the sample image to the appropriate device
sample_image = sample_image.to(device).unsqueeze(0)  # Add batch dimension

# Make a prediction
with torch.no_grad():
    prediction = best_trained_model(sample_image)

# Convert the prediction to a binary mask
predicted_mask = (prediction > 0.5).float()

# Plot the sample image, ground truth mask, and predicted mask
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

ax[0].imshow(sample_image.squeeze().permute(1, 2, 0).cpu().numpy())
ax[0].set_title("Sample Image")
ax[0].axis('off')

ax[1].imshow(sample_mask.squeeze().cpu().numpy(), cmap='gray')
ax[1].set_title("Ground Truth Mask")
ax[1].axis('off')

ax[2].imshow(predicted_mask.squeeze().cpu().numpy(), cmap='gray')
ax[2].set_title("Predicted Mask")
ax[2].axis('off')

plt.show()
# Out:
# 2024-11-26 16:39:38,781	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 40 trial(s):
# - train_model_cv_83259_00005: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00005: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00005_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00022: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00022: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00022_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00017: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00017: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00017_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00033: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00033: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00033_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00015: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00015: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00015_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00010: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00010: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00010_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00009: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00009: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00009_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00013: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00013: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00013_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00023: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00023: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00023_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00029: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00029: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00029_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00030: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00030: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00030_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00040: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00040: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00040_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00044: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00044: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00044_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00034: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00034: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00034_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00020: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00020: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00020_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00025: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00025: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00025_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00028: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00028: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00028_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00032: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00032: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00032_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00039: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00039: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00039_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00031: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00031: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00031_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00035: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00035: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00035_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00036: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00036: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00036_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00012: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00012: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00012_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00016: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00016: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00016_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00019: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00019: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00019_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00024: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00024: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00024_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00042: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00042: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00042_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00018: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00018: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00018_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00011: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00011: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00011_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00021: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00021: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00021_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00038: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00038: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00038_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00006: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00006: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00006_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00014: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00014: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00014_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00027: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00027: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00027_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00041: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00041: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00041_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00043: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00043: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00043_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00007: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00007: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00007_lr=1.0e-04_opt=Adam_bs=4')
# - train_model_cv_83259_00026: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00026: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00026_lr=1.0e-04_opt=SGD_bs=4')
# - train_model_cv_83259_00037: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00037: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00037_lr=1.0e-04_opt=RMSprop_bs=4')
# - train_model_cv_83259_00008: FileNotFoundError('Could not fetch metrics for train_model_cv_83259_00008: both result.json and progress.csv were not found at C:/Users/johan/ray_results/train_model_cv_2024-11-26_16-31-22/trial_83259_00008_lr=1.0e-04_opt=Adam_bs=4')
# Loading results from C:\Users\johan\ray_results\train_model_cv_2024-11-26_16-31-22...
# One of the trials failed!
# Number of results: 45
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 27
#      24         print(f"Trial #{i} had an error:", result.error)
#      25         continue
# ---> 27     print(f"Trial #{i} finished successfully with a loss of: {result.metrics['loss']}")
#      29 results_df = result_grid.get_dataframe()
#      30 results_df[["training_iteration", "loss"]]
#
# KeyError: 'loss'
